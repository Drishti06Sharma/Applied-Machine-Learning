# %%
print("Hello Dhriti")
# Out:
# Hello Dhriti

# %%
import numpy as np
rooms=np.array

# %%
prices = [29.99, 49.99, 19.99]
quantities = [1, 2, 3]

# %%
import numpy as np

prices = np.array([29.99, 49.99, 19.99])
quantities = np.array([1, 2, 3])

print("Prices:", prices)
print("Quantities:", quantities)
# Out:
# Prices: [29.99 49.99 19.99]
# Quantities: [1 2 3]

# %%
# %pip install numpy
# Out:
# ...
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#     --------------------------------------- 0.3/12.6 MB ? eta -:--:--
#     --------------------------------------- 0.3/12.6 MB ? eta -:--:--
#    - -------------------------------------- 0.5/12.6 MB 805.5 kB/s eta 0:00:15
#    -- ------------------------------------- 0.8/12.6 MB 1.1 MB/s eta 0:00:11
#    --- ------------------------------------ 1.0/12.6 MB 1.0 MB/s eta 0:00:12
#    ---- ----------------------------------- 1.3/12.6 MB 1.1 MB/s eta 0:00:11
#    ---- ----------------------------------- 1.6/12.6 MB 1.1 MB/s eta 0:00:10
#    ----- ---------------------------------- 1.8/12.6 MB 1.1 MB/s eta 0:00:10
#    ----- ---------------------------------- 1.8/12.6 MB 1.1 MB/s eta 0:00:10
#    ----- ---------------------------------- 1.8/12.6 MB 1.1 MB/s eta 0:00:10
# ...

# %%
revenue = prices * quantities

print("Revenue:", revenue)
# Out:
# Revenue: [29.99 99.98 59.97]

# %%
mean_price = np.mean(prices)
std_price = np.std(prices)

expensive_items = prices[prices > 40]

print("Mean:", mean_price)
print("Standard Deviation:", std_price)
print("Items priced over $40:", expensive_items)
# Out:
# Mean: 33.32333333333333
# Standard Deviation: 12.472191289246473
# Items priced over $40: [49.99]
