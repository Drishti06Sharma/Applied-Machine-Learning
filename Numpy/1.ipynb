# %%
import numpy as np

X = np.array([1, 2, 3, 4, 5])
y = np.array([35, 40, 50, 55, 65])

m, c = np.polyfit(X, y, 1)
print('Slope:', m)
print('Intercept:', c)
y_pred=m*X + c
# Out:
# Slope: 7.500000000000001
# Intercept: 26.499999999999982

# %%
import numpy as np
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

y = np.array([50, 60, 70, 80, 90])
y_pred = np.array([52, 61, 68, 79, 91])

mae = mean_absolute_error(y, y_pred)
mse = mean_squared_error(y, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y, y_pred)

print("MAE :", mae)
print("MSE :", mse)
print("RMSE:", rmse)
print("R²  :", r2)
# Out:
# MAE : 1.4
# MSE : 2.2
# RMSE: 1.4832396974191326
# R²  : 0.989
